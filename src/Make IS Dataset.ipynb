# %% [markdown]
# #

# %%
import os

import shutil
import glob

# %% [markdown]
# Path = os.path.join("","","")

# %%
num_samples =  5
name = "test"
path = os.path.join(".","output_cfg_9",f"{name}")
pre_path = os.path.join(".","output_cfg_9", f"{name}_preds")

names_list = glob.glob(os.path.join(path, "*"))
os.makedirs(pre_path, exist_ok=True)
for n in names_list:
    if n.endswith("0.png"):
        continue

    shutil.copyfile(n, n.replace(name, f"{name}_preds"))
